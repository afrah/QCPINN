# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Plot Training Loss History of Helmholtz Problem
#
# We already saved the training loss history in the saved checkpoints.

# %%
run -m src.testing.cavity_test
# Out:
# INFO:src.utils.logger:Model loaded successfully from ./models/cavity_amplitude/2025-02-12_16-32-09-851527/model.pth
# INFO:src.utils.logger:Using DV Solver
# INFO:src.utils.logger:Total number of iterations : 20000
# INFO:src.utils.logger:The final loss : 0.13128572702407837
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Method used: angle_layered
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 0.13128572702407837
# INFO:src.utils.logger:Total number of parameters: 928
# INFO:src.utils.logger:File directory: ./models/cavity_amplitude/2025-02-12_16-32-09-851527
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Model loaded successfully from ./models/cavity_amplitude/2025-02-06_19-28-34-814985/model.pth
# INFO:src.utils.logger:Using DV Solver
# INFO:src.utils.logger:Total number of iterations : 18100
# INFO:src.utils.logger:The final loss : 0.0921594500541687
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Method used: angle_cascade
# INFO:src.utils.logger:Total iterations: 18100
# INFO:src.utils.logger:Final loss: 0.0921594500541687
# INFO:src.utils.logger:Total number of parameters: 923
# INFO:src.utils.logger:File directory: ./models/cavity_amplitude/2025-02-06_19-28-34-814985
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Model loaded successfully from ./models/cavity_amplitude/2025-02-06_19-28-52-910332/model.pth
# INFO:src.utils.logger:Using DV Solver
# INFO:src.utils.logger:Total number of iterations : 12350
# INFO:src.utils.logger:The final loss : 0.14721782505512238
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Method used: angle_cross_mesh
# INFO:src.utils.logger:Total iterations: 12350
# INFO:src.utils.logger:Final loss: 0.14721782505512238
# INFO:src.utils.logger:Total number of parameters: 983
# INFO:src.utils.logger:File directory: ./models/cavity_amplitude/2025-02-06_19-28-52-910332
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Model loaded successfully from ./models/cavity_amplitude/2025-02-06_19-27-57-462145/model.pth
# INFO:src.utils.logger:Using DV Solver
# INFO:src.utils.logger:Total number of iterations : 16650
# INFO:src.utils.logger:The final loss : 0.060502439737319946
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Method used: angle_alternate
# INFO:src.utils.logger:Total iterations: 16650
# INFO:src.utils.logger:Final loss: 0.060502439737319946
# INFO:src.utils.logger:Total number of parameters: 928
# INFO:src.utils.logger:File directory: ./models/cavity_amplitude/2025-02-06_19-27-57-462145
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Model loaded successfully from ./models/cavity_amplitude/2025-02-12_16-32-09-865339/model.pth
# INFO:src.utils.logger:Using DV Solver
# INFO:src.utils.logger:Total number of iterations : 20000
# INFO:src.utils.logger:The final loss : 0.15650705993175507
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Method used: amp_layered
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 0.15650705993175507
# INFO:src.utils.logger:Total number of parameters: 928
# INFO:src.utils.logger:File directory: ./models/cavity_amplitude/2025-02-12_16-32-09-865339
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Model loaded successfully from ./models/cavity_amplitude/2025-02-06_18-44-40-359259/model.pth
# INFO:src.utils.logger:Using DV Solver
# INFO:src.utils.logger:Total number of iterations : 20000
# INFO:src.utils.logger:The final loss : 0.08443133533000946
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Method used: amp_alternate
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 0.08443133533000946
# INFO:src.utils.logger:Total number of parameters: 928
# INFO:src.utils.logger:File directory: ./models/cavity_amplitude/2025-02-06_18-44-40-359259
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Model loaded successfully from ./models/cavity_amplitude/2025-02-06_18-29-51-200273/model.pth
# INFO:src.utils.logger:Using DV Solver
# INFO:src.utils.logger:Total number of iterations : 15200
# INFO:src.utils.logger:The final loss : 0.07391476631164551
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Method used: amp_cross_mesh
# INFO:src.utils.logger:Total iterations: 15200
# INFO:src.utils.logger:Final loss: 0.07391476631164551
# INFO:src.utils.logger:Total number of parameters: 983
# INFO:src.utils.logger:File directory: ./models/cavity_amplitude/2025-02-06_18-29-51-200273
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Model loaded successfully from ./models/cavity_amplitude/2025-02-06_18-41-52-938544/model.pth
# INFO:src.utils.logger:Using DV Solver
# INFO:src.utils.logger:Total number of iterations : 20000
# INFO:src.utils.logger:The final loss : 0.10414154082536697
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Method used: amp_cascade
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 0.10414154082536697
# INFO:src.utils.logger:Total number of parameters: 923
# INFO:src.utils.logger:File directory: ./models/cavity_amplitude/2025-02-06_18-41-52-938544
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:checkpoint path: self.log_path='/home/khans/afrah/code/QCPINN/src/testing_checkpoints/cavity/2025-04-26_20-14-42-813948'
# INFO:src.utils.logger:Model loaded successfully from ./models/cavity_amplitude/2025-02-25_17-21-36-221407/model.pth
# INFO:src.utils.logger:Using Classical Solver
# INFO:src.utils.logger:Total number of iterations : 20001
# INFO:src.utils.logger:The final loss : 0.08730538189411163
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:Method used: classical
# INFO:src.utils.logger:Total iterations: 20001
# INFO:src.utils.logger:Final loss: 0.08730538189411163
# INFO:src.utils.logger:Total number of parameters: 8003
# INFO:src.utils.logger:File directory: ./models/cavity_amplitude/2025-02-25_17-21-36-221407
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
# Model state loaded from ./models/cavity_amplitude/2025-02-12_16-32-09-851527/model.pth
# Model state loaded from ./models/cavity_amplitude/2025-02-06_19-28-34-814985/model.pth
# Model state loaded from ./models/cavity_amplitude/2025-02-06_19-28-52-910332/model.pth
# Model state loaded from ./models/cavity_amplitude/2025-02-06_19-27-57-462145/model.pth
# Model state loaded from ./models/cavity_amplitude/2025-02-12_16-32-09-865339/model.pth
# Model state loaded from ./models/cavity_amplitude/2025-02-06_18-44-40-359259/model.pth
# Model state loaded from ./models/cavity_amplitude/2025-02-06_18-29-51-200273/model.pth
# Model state loaded from ./models/cavity_amplitude/2025-02-06_18-41-52-938544/model.pth
# Model state loaded from ./models/cavity_amplitude/2025-02-25_17-21-36-221407/model.pth
# Model state loaded from ./models/cavity_amplitude/2025-02-25_17-21-36-221407/model.pth
#
# Loss values at iteration 12500:
# ----------------------------------------
# angle_layered       : 0.129471
# angle_cascade       : 0.083034
# angle_cross_mesh    : 0.083705
# angle_alternate     : 0.109232
# amp_layered         : 0.120854
# amp_alternate       : 0.126841
# amp_cross_mesh      : 0.108576
# amp_cascade         : 0.123187
# classical           : 0.078146
# ----------------------------------------
