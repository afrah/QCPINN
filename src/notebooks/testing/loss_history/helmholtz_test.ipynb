# %% [markdown]
# ## Plot Training Loss History of Helmholtz Problem
#
# We already saved the training loss history in the saved checkpoints.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import torch
import numpy as np

# %%
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "./"))

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from src.utils.logger import Logging
from src.utils.plot_loss import plot_loss_history
from src.utils.color import model_color
from src.poisson.cv_solver import CVPDESolver
from src.poisson.dv_solver import DVPDESolver
from src.poisson.classical_solver import Classical_Solver
from src.nn.pde import helmholtz_operator
from src.data.helmholtz_dataset import u, f
# Out:
# /okyanus/users/afarea/anaconda3_2021/envs/pennylane_env/lib/python3.9/site-packages/torch/cuda/__init__.py:107: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 8000). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
run -m src.contour_plots.plotting_loss_history.helmholtz_test
# Out:
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: angle_layered
# INFO:src.utils.logger:Total number of parameters: 776
# INFO:src.utils.logger:Method used: angle_layered
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 11.510710716247559
# INFO:src.utils.logger:File directory: ./log_files/checkpoints/helmholtz/2025-02-12_16-33-22-249802
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: angle_cascade
# INFO:src.utils.logger:Total number of parameters: 771
# INFO:src.utils.logger:Method used: angle_cascade
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 3.630709648132324
# INFO:src.utils.logger:File directory: ./log_files/checkpoints/helmholtz/2025-02-06_19-25-14-069398
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: angle_cross_mesh
# INFO:src.utils.logger:Total number of parameters: 831
# INFO:src.utils.logger:Method used: angle_cross_mesh
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 5.82295036315918
# INFO:src.utils.logger:File directory: ./log_files/checkpoints/helmholtz/2025-02-06_19-32-04-408294
# INFO:src.utils.logger:******************************
# Model state loaded from ./log_files/checkpoints/helmholtz/2025-02-12_16-33-22-249802/model.pth
# Model state loaded from ./log_files/checkpoints/helmholtz/2025-02-06_19-25-14-069398/model.pth
# Model state loaded from ./log_files/checkpoints/helmholtz/2025-02-06_19-32-04-408294/model.pth
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: angle_alternate
# INFO:src.utils.logger:Total number of parameters: 776
# INFO:src.utils.logger:Method used: angle_alternate
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 11.456033706665039
# INFO:src.utils.logger:File directory: ./log_files/checkpoints/helmholtz/2025-02-06_19-25-14-069609
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: amp_layered
# INFO:src.utils.logger:Total number of parameters: 776
# INFO:src.utils.logger:Method used: amp_layered
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 39.44567108154297
# INFO:src.utils.logger:File directory: ./log_files/checkpoints/helmholtz/2025-02-12_16-33-59-543343
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: amp_alternate
# INFO:src.utils.logger:Total number of parameters: 776
# INFO:src.utils.logger:Method used: amp_alternate
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 55.36176681518555
# INFO:src.utils.logger:File directory: ./log_files/checkpoints/helmholtz/2025-02-06_18-54-03-851796
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: amp_cross_mesh
# INFO:src.utils.logger:Total number of parameters: 831
# INFO:src.utils.logger:Method used: amp_cross_mesh
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 6.872259140014648
# INFO:src.utils.logger:File directory: ./log_files/checkpoints/helmholtz/2025-02-06_18-52-46-865258
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: amp_cascade
# INFO:src.utils.logger:Total number of parameters: 771
# INFO:src.utils.logger:Method used: amp_cascade
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 6.372251510620117
# INFO:src.utils.logger:File directory: ./log_files/checkpoints/helmholtz/2025-02-06_18-48-39-607215
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:checkpoint path: self.log_path='/okyanus/users/afarea/afrah/code/QNN4PDEs/testing_checkpoints/helmholtz/2025-02-25_18-33-37-530469'
# INFO:src.utils.logger:Error processing model classical: Error(s) in loading state_dict for Sequential:
# 	Unexpected key(s) in state_dict: "2.weight", "2.bias".
# Model state loaded from ./log_files/checkpoints/helmholtz/2025-02-06_19-25-14-069609/model.pth
# Model state loaded from ./log_files/checkpoints/helmholtz/2025-02-12_16-33-59-543343/model.pth
# Model state loaded from ./log_files/checkpoints/helmholtz/2025-02-06_18-54-03-851796/model.pth
# Model state loaded from ./log_files/checkpoints/helmholtz/2025-02-06_18-52-46-865258/model.pth
# Model state loaded from ./log_files/checkpoints/helmholtz/2025-02-06_18-48-39-607215/model.pth
# Model state loaded from ./log_files/checkpoints/helmholtz/2025-02-25_11-40-47-649912/model.pth
# Error loading model from ./log_files/checkpoints/helmholtz/2025-02-25_11-40-47-649912: Error(s) in loading state_dict for Sequential:
# 	Unexpected key(s) in state_dict: "2.weight", "2.bias".
#
# Loss values at iteration 12500:
# ----------------------------------------
# angle_layered       : 14.132232
# angle_cascade       : 3.302162
# angle_cross_mesh    : 7.022034
# angle_alternate     : 11.867549
# amp_layered         : 24.751720
# amp_alternate       : 63.888417
# amp_cross_mesh      : 6.301809
# amp_cascade         : 5.359718
# ----------------------------------------
