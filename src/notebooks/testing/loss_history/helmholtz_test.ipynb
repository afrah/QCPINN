# %% [markdown]
# ## Plot Training Loss History of Helmholtz Problem
#
# We already saved the training loss history in the saved checkpoints.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
run -m src.testing.helmholtz_test
# Out:
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: angle_layered
# INFO:src.utils.logger:Total number of parameters: 776
# INFO:src.utils.logger:Method used: angle_layered
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 11.510710716247559
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-12_16-33-22-249802
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: angle_cascade
# INFO:src.utils.logger:Total number of parameters: 771
# INFO:src.utils.logger:Method used: angle_cascade
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 3.630709648132324
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-06_19-25-14-069398
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: angle_cross_mesh
# INFO:src.utils.logger:Total number of parameters: 831
# INFO:src.utils.logger:Method used: angle_cross_mesh
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 5.82295036315918
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-06_19-32-04-408294
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: angle_alternate
# INFO:src.utils.logger:Total number of parameters: 776
# INFO:src.utils.logger:Method used: angle_alternate
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 11.456033706665039
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-06_19-25-14-069609
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: amp_layered
# INFO:src.utils.logger:Total number of parameters: 776
# INFO:src.utils.logger:Method used: amp_layered
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 39.44567108154297
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-12_16-33-59-543343
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: amp_alternate
# INFO:src.utils.logger:Total number of parameters: 776
# INFO:src.utils.logger:Method used: amp_alternate
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 55.36176681518555
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-06_18-54-03-851796
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: amp_cross_mesh
# INFO:src.utils.logger:Total number of parameters: 831
# INFO:src.utils.logger:Method used: amp_cross_mesh
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 6.872259140014648
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-06_18-52-46-865258
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: amp_cascade
# INFO:src.utils.logger:Total number of parameters: 771
# INFO:src.utils.logger:Method used: amp_cascade
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 6.372251510620117
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-06_18-48-39-607215
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:checkpoint path: self.log_path='/home/khans/afrah/code/QCPINN/src/testing_checkpoints/helmholtz/2025-04-26_20-15-12-725457'
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:
# Processing model: classical
# INFO:src.utils.logger:Total number of parameters: 2751
# INFO:src.utils.logger:Method used: classical
# INFO:src.utils.logger:Total iterations: 20000
# INFO:src.utils.logger:Final loss: 6.134862422943115
# INFO:src.utils.logger:File directory: ./models/helmholtz_amplitude/2025-02-09_00-01-28-238904
# INFO:src.utils.logger:******************************
# Model state loaded from ./models/helmholtz_amplitude/2025-02-12_16-33-22-249802/model.pth
# Model state loaded from ./models/helmholtz_amplitude/2025-02-06_19-25-14-069398/model.pth
# Model state loaded from ./models/helmholtz_amplitude/2025-02-06_19-32-04-408294/model.pth
# Model state loaded from ./models/helmholtz_amplitude/2025-02-06_19-25-14-069609/model.pth
# Model state loaded from ./models/helmholtz_amplitude/2025-02-12_16-33-59-543343/model.pth
# Model state loaded from ./models/helmholtz_amplitude/2025-02-06_18-54-03-851796/model.pth
# Model state loaded from ./models/helmholtz_amplitude/2025-02-06_18-52-46-865258/model.pth
# Model state loaded from ./models/helmholtz_amplitude/2025-02-06_18-48-39-607215/model.pth
# Model state loaded from ./models/helmholtz_amplitude/2025-02-09_00-01-28-238904/model.pth
#
# Loss values at iteration 12500:
# ----------------------------------------
# angle_layered       : 14.132232
# angle_cascade       : 3.302162
# angle_cross_mesh    : 7.022034
# angle_alternate     : 11.867549
# amp_layered         : 24.751720
# amp_alternate       : 63.888417
# amp_cross_mesh      : 6.301809
# amp_cascade         : 5.359718
# classical           : 4.775127
# ----------------------------------------
